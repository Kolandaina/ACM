# %%
import torch
from torch import nn
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from d2l import torch as d2l
# 定义网络
net = nn.Sequential(
    nn.Conv2d(1, 96, kernel_size=11, stride=4, padding=2), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    nn.Conv2d(96, 128*2, kernel_size=5, padding=2), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    nn.Conv2d(128*2, 192*2, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(192*2, 192*2, kernel_size=3, padding=1), nn.ReLU(),
    nn.Conv2d(192*2, 128*2, kernel_size=3, padding=1), nn.ReLU(),
    nn.MaxPool2d(kernel_size=3, stride=2),
    nn.Flatten(),
    nn.Linear(6*6*256, 2048*2), nn.ReLU(), nn.Dropout(p=0.5),
    nn.Linear(2048*2, 2048*2), nn.ReLU(), nn.Dropout(p=0.5),
    nn.Linear(2048*2, 10), nn.ReLU(),
)
# 下载并配置数据集
trans = [transforms.ToTensor()]
trans.insert(0, transforms.Resize(224))
trans = transforms.Compose(trans)
train_dataset = datasets.FashionMNIST(root='./dataset', train=True,
                                      transform=trans, download=True)
test_dataset = datasets.FashionMNIST(root='./dataset', train=False,
                                     transform=trans, download=True)

# 配置数据加载器
batch_size = 64
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size, shuffle=True)
def train(net, train_iter, test_iter, epochs, lr, device):
    def init_weights(m):
        if type(m) == nn.Linear or type(m) == nn.Conv2d:
            nn.init.xavier_uniform_(m.weight)
    net.apply(init_weights)
    print(f'Training on:[{device}]')
    net.to(device)
    optimizer = torch.optim.SGD(net.parameters(), lr=lr)
    loss = nn.CrossEntropyLoss()
    timer, num_batches = d2l.Timer(), len(train_iter)
    for epoch in range(epochs):
        # 训练损失之和，训练准确率之和，样本数
        metric = d2l.Accumulator(3)
        net.train()
        for i, (X, y) in enumerate(train_iter):
            timer.start()
            optimizer.zero_grad()
            X, y = X.to(device), y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            l.backward()
            optimizer.step()
            with torch.no_grad():
                metric.add(l * X.shape[0], d2l.accuracy(y_hat, y), X.shape[0])
            timer.stop()
            train_l = metric[0] / metric[2]
            train_acc = metric[1] / metric[2]
            if (i + 1) % (num_batches // 30) == 0 or i == num_batches - 1:
                print(f'Epoch: {epoch+1}, Step: {i+1}, Loss: {train_l:.4f}')
        test_acc = d2l.evaluate_accuracy_gpu(net, test_iter)
        print(
            f'Train Accuracy: {train_acc*100:.2f}%, Test Accuracy: {test_acc*100:.2f}%')
    print(f'{metric[2] * epochs / timer.sum():.1f} examples/sec '
          f'on: [{str(device)}]')
    torch.save(net.state_dict(),
               f"./model/AlexNet_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
epochs, lr = 10, 0.1
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# 训练模型
train(net, train_loader, test_loader, epochs, lr, device)
# 加载保存的模型
# net.load_state_dict(torch.load("./model/AlexNet_Epoch20_Accuracy91.38%.pth"))
def show_predict():
    # 预测结果图像可视化
    net.to(device)
    loader = DataLoader(dataset=test_dataset, batch_size=1, shuffle=True)
    plt.figure(figsize=(12, 8))
    name = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
            'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
    for i in range(9):
        (images, labels) = next(iter(loader))
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        title = f"Predicted: {name[int(predicted[0])]}, True: {name[int(labels[0])]}"
        plt.subplot(3, 3, i + 1)
        plt.imshow(images.cpu()[0].squeeze())
        plt.title(title)
        plt.xticks([])
        plt.yticks([])
    plt.show()


show_predict()
# Out:
# Training on:[cuda:0]
# d:\1-programme\porgramme\miniconda3\envs\test1\lib\site-packages\torch\nn\modules\conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# Epoch: 1, Step: 31, Loss: 2.2880
# Epoch: 1, Step: 62, Loss: 2.2421
# Epoch: 1, Step: 93, Loss: 2.2029
# Epoch: 1, Step: 124, Loss: 2.1749
# Epoch: 1, Step: 155, Loss: 2.1425
# Epoch: 1, Step: 186, Loss: 2.1064
# Epoch: 1, Step: 217, Loss: 2.0634
# Epoch: 1, Step: 248, Loss: 2.0107
# Epoch: 1, Step: 279, Loss: 1.9637
# Epoch: 1, Step: 310, Loss: 1.9274
# Epoch: 1, Step: 341, Loss: 1.8985
# Epoch: 1, Step: 372, Loss: 1.8699
# Epoch: 1, Step: 403, Loss: 1.8488
# Epoch: 1, Step: 434, Loss: 1.8259
# Epoch: 1, Step: 465, Loss: 1.8069
# Epoch: 1, Step: 496, Loss: 1.7901
# Epoch: 1, Step: 527, Loss: 1.7752
# Epoch: 1, Step: 558, Loss: 1.7611
# Epoch: 1, Step: 589, Loss: 1.7475
# Epoch: 1, Step: 620, Loss: 1.7353
# Epoch: 1, Step: 651, Loss: 1.7233
# Epoch: 1, Step: 682, Loss: 1.7139
# Epoch: 1, Step: 713, Loss: 1.7052
# Epoch: 1, Step: 744, Loss: 1.6976
# Epoch: 1, Step: 775, Loss: 1.6898
# Epoch: 1, Step: 806, Loss: 1.6824
# Epoch: 1, Step: 837, Loss: 1.6749
# Epoch: 1, Step: 868, Loss: 1.6688
# Epoch: 1, Step: 899, Loss: 1.6634
# Epoch: 1, Step: 930, Loss: 1.6583
# Epoch: 1, Step: 938, Loss: 1.6562
# Train Accuracy: 40.84%, Test Accuracy: 47.23%
# Epoch: 2, Step: 31, Loss: 1.4650
# Epoch: 2, Step: 62, Loss: 1.4739
# Epoch: 2, Step: 93, Loss: 1.4836
# Epoch: 2, Step: 124, Loss: 1.4780
# Epoch: 2, Step: 155, Loss: 1.4768
# Epoch: 2, Step: 186, Loss: 1.4753
# Epoch: 2, Step: 217, Loss: 1.4805
# Epoch: 2, Step: 248, Loss: 1.4878
# Epoch: 2, Step: 279, Loss: 1.4865
# Epoch: 2, Step: 310, Loss: 1.4832
# Epoch: 2, Step: 341, Loss: 1.4812
# Epoch: 2, Step: 372, Loss: 1.4828
# Epoch: 2, Step: 403, Loss: 1.4806
# Epoch: 2, Step: 434, Loss: 1.4806
# Epoch: 2, Step: 465, Loss: 1.4784
# Epoch: 2, Step: 496, Loss: 1.4764
# Epoch: 2, Step: 527, Loss: 1.4755
# Epoch: 2, Step: 558, Loss: 1.4720
# Epoch: 2, Step: 589, Loss: 1.4721
# Epoch: 2, Step: 620, Loss: 1.4717
# Epoch: 2, Step: 651, Loss: 1.4710
# Epoch: 2, Step: 682, Loss: 1.4732
# Epoch: 2, Step: 713, Loss: 1.4727
# Epoch: 2, Step: 744, Loss: 1.4729
# Epoch: 2, Step: 775, Loss: 1.4735
# Epoch: 2, Step: 806, Loss: 1.4737
# Epoch: 2, Step: 837, Loss: 1.4732
# Epoch: 2, Step: 868, Loss: 1.4731
# Epoch: 2, Step: 899, Loss: 1.4723
# Epoch: 2, Step: 930, Loss: 1.4715
# Epoch: 2, Step: 938, Loss: 1.4717
# Train Accuracy: 47.55%, Test Accuracy: 47.96%
# Epoch: 3, Step: 31, Loss: 1.4488
# Epoch: 3, Step: 62, Loss: 1.4676
# Epoch: 3, Step: 93, Loss: 1.4713
# Epoch: 3, Step: 124, Loss: 1.4653
# Epoch: 3, Step: 155, Loss: 1.4672
# Epoch: 3, Step: 186, Loss: 1.4694
# Epoch: 3, Step: 217, Loss: 1.4667
# Epoch: 3, Step: 248, Loss: 1.4634
# Epoch: 3, Step: 279, Loss: 1.4650
# Epoch: 3, Step: 310, Loss: 1.4668
# Epoch: 3, Step: 341, Loss: 1.4664
# Epoch: 3, Step: 372, Loss: 1.4640
# Epoch: 3, Step: 403, Loss: 1.4662
# Epoch: 3, Step: 434, Loss: 1.4624
# Epoch: 3, Step: 465, Loss: 1.4636
# Epoch: 3, Step: 496, Loss: 1.4602
# Epoch: 3, Step: 527, Loss: 1.4606
# Epoch: 3, Step: 558, Loss: 1.4613
# Epoch: 3, Step: 589, Loss: 1.4598
# Epoch: 3, Step: 620, Loss: 1.4595
# Epoch: 3, Step: 651, Loss: 1.4609
# Epoch: 3, Step: 682, Loss: 1.4610
# Epoch: 3, Step: 713, Loss: 1.4597
# Epoch: 3, Step: 744, Loss: 1.4592
# Epoch: 3, Step: 775, Loss: 1.4592
# Epoch: 3, Step: 806, Loss: 1.4582
# Epoch: 3, Step: 837, Loss: 1.4589
# Epoch: 3, Step: 868, Loss: 1.4579
# Epoch: 3, Step: 899, Loss: 1.4585
# Epoch: 3, Step: 930, Loss: 1.4572
# Epoch: 3, Step: 938, Loss: 1.4569
# Train Accuracy: 47.96%, Test Accuracy: 47.35%
# Epoch: 4, Step: 31, Loss: 1.4453
# Epoch: 4, Step: 62, Loss: 1.4650
# Epoch: 4, Step: 93, Loss: 1.4639
# Epoch: 4, Step: 124, Loss: 1.4510
# Epoch: 4, Step: 155, Loss: 1.4512
# Epoch: 4, Step: 186, Loss: 1.4505
# Epoch: 4, Step: 217, Loss: 1.4549
# Epoch: 4, Step: 248, Loss: 1.4569
# Epoch: 4, Step: 279, Loss: 1.4529
# Epoch: 4, Step: 310, Loss: 1.4550
# Epoch: 4, Step: 341, Loss: 1.4541
# Epoch: 4, Step: 372, Loss: 1.4536
# Epoch: 4, Step: 403, Loss: 1.4529
# Epoch: 4, Step: 434, Loss: 1.4524
# Epoch: 4, Step: 465, Loss: 1.4517
# Epoch: 4, Step: 496, Loss: 1.4495
# Epoch: 4, Step: 527, Loss: 1.4493
# Epoch: 4, Step: 558, Loss: 1.4490
# Epoch: 4, Step: 589, Loss: 1.4463
# Epoch: 4, Step: 620, Loss: 1.4477
# Epoch: 4, Step: 651, Loss: 1.4496
# Epoch: 4, Step: 682, Loss: 1.4511
# Epoch: 4, Step: 713, Loss: 1.4498
# Epoch: 4, Step: 744, Loss: 1.4497
# Epoch: 4, Step: 775, Loss: 1.4477
# Epoch: 4, Step: 806, Loss: 1.4479
# Epoch: 4, Step: 837, Loss: 1.4467
# Epoch: 4, Step: 868, Loss: 1.4479
# Epoch: 4, Step: 899, Loss: 1.4469
# Epoch: 4, Step: 930, Loss: 1.4477
# Epoch: 4, Step: 938, Loss: 1.4479
# Train Accuracy: 48.22%, Test Accuracy: 48.66%
# Epoch: 5, Step: 31, Loss: 1.4370
# Epoch: 5, Step: 62, Loss: 1.4225
# Epoch: 5, Step: 93, Loss: 1.4351
# Epoch: 5, Step: 124, Loss: 1.4427
# Epoch: 5, Step: 155, Loss: 1.4453
# Epoch: 5, Step: 186, Loss: 1.4506
# Epoch: 5, Step: 217, Loss: 1.4464
# Epoch: 5, Step: 248, Loss: 1.4456
# Epoch: 5, Step: 279, Loss: 1.4418
# Epoch: 5, Step: 310, Loss: 1.4481
# Epoch: 5, Step: 341, Loss: 1.4502
# Epoch: 5, Step: 372, Loss: 1.4469
# Epoch: 5, Step: 403, Loss: 1.4423
# Epoch: 5, Step: 434, Loss: 1.4343
# Epoch: 5, Step: 465, Loss: 1.4265
# Epoch: 5, Step: 496, Loss: 1.4185
# Epoch: 5, Step: 527, Loss: 1.4157
# Epoch: 5, Step: 558, Loss: 1.4119
# Epoch: 5, Step: 589, Loss: 1.4063
# Epoch: 5, Step: 620, Loss: 1.4037
# Epoch: 5, Step: 651, Loss: 1.4006
# Epoch: 5, Step: 682, Loss: 1.3975
# Epoch: 5, Step: 713, Loss: 1.3922
# Epoch: 5, Step: 744, Loss: 1.3878
# Epoch: 5, Step: 775, Loss: 1.3843
# Epoch: 5, Step: 806, Loss: 1.3823
# Epoch: 5, Step: 837, Loss: 1.3789
# Epoch: 5, Step: 868, Loss: 1.3758
# Epoch: 5, Step: 899, Loss: 1.3726
# Epoch: 5, Step: 930, Loss: 1.3692
# Epoch: 5, Step: 938, Loss: 1.3684
# Train Accuracy: 53.37%, Test Accuracy: 56.86%
# Epoch: 6, Step: 31, Loss: 1.3204
# Epoch: 6, Step: 62, Loss: 1.3150
# Epoch: 6, Step: 93, Loss: 1.3061
# Epoch: 6, Step: 124, Loss: 1.3055
# Epoch: 6, Step: 155, Loss: 1.2938
# Epoch: 6, Step: 186, Loss: 1.2889
# Epoch: 6, Step: 217, Loss: 1.2919
# Epoch: 6, Step: 248, Loss: 1.2943
# Epoch: 6, Step: 279, Loss: 1.2908
# Epoch: 6, Step: 310, Loss: 1.2860
# Epoch: 6, Step: 341, Loss: 1.2873
# Epoch: 6, Step: 372, Loss: 1.2886
# Epoch: 6, Step: 403, Loss: 1.2864
# Epoch: 6, Step: 434, Loss: 1.2904
# Epoch: 6, Step: 465, Loss: 1.2880
# Epoch: 6, Step: 496, Loss: 1.2872
# Epoch: 6, Step: 527, Loss: 1.2885
# Epoch: 6, Step: 558, Loss: 1.2882
# Epoch: 6, Step: 589, Loss: 1.2909
# Epoch: 6, Step: 620, Loss: 1.2901
# Epoch: 6, Step: 651, Loss: 1.2901
# Epoch: 6, Step: 682, Loss: 1.2894
# Epoch: 6, Step: 713, Loss: 1.2878
# Epoch: 6, Step: 744, Loss: 1.2856
# Epoch: 6, Step: 775, Loss: 1.2850
# Epoch: 6, Step: 806, Loss: 1.2844
# Epoch: 6, Step: 837, Loss: 1.2821
# Epoch: 6, Step: 868, Loss: 1.2832
# Epoch: 6, Step: 899, Loss: 1.2832
# Epoch: 6, Step: 930, Loss: 1.2835
# Epoch: 6, Step: 938, Loss: 1.2837
# Train Accuracy: 57.28%, Test Accuracy: 57.27%
# Epoch: 7, Step: 31, Loss: 1.2711
# Epoch: 7, Step: 62, Loss: 1.3014
# Epoch: 7, Step: 93, Loss: 1.2789
# Epoch: 7, Step: 124, Loss: 1.2770
# Epoch: 7, Step: 155, Loss: 1.2802
# Epoch: 7, Step: 186, Loss: 1.2798
# Epoch: 7, Step: 217, Loss: 1.2728
# Epoch: 7, Step: 248, Loss: 1.2743
# Epoch: 7, Step: 279, Loss: 1.2696
# Epoch: 7, Step: 310, Loss: 1.2691
# Epoch: 7, Step: 341, Loss: 1.2706
# Epoch: 7, Step: 372, Loss: 1.2696
# Epoch: 7, Step: 403, Loss: 1.2672
# Epoch: 7, Step: 434, Loss: 1.2673
# Epoch: 7, Step: 465, Loss: 1.2653
# Epoch: 7, Step: 496, Loss: 1.2654
# Epoch: 7, Step: 527, Loss: 1.2659
# Epoch: 7, Step: 558, Loss: 1.2670
# Epoch: 7, Step: 589, Loss: 1.2668
# Epoch: 7, Step: 620, Loss: 1.2676
# Epoch: 7, Step: 651, Loss: 1.2653
# Epoch: 7, Step: 682, Loss: 1.2662
# Epoch: 7, Step: 713, Loss: 1.2645
# Epoch: 7, Step: 744, Loss: 1.2660
# Epoch: 7, Step: 775, Loss: 1.2664
# Epoch: 7, Step: 806, Loss: 1.2664
# Epoch: 7, Step: 837, Loss: 1.2654
# Epoch: 7, Step: 868, Loss: 1.2654
# Epoch: 7, Step: 899, Loss: 1.2665
# Epoch: 7, Step: 930, Loss: 1.2661
# Epoch: 7, Step: 938, Loss: 1.2659
# Train Accuracy: 57.62%, Test Accuracy: 57.52%
# Epoch: 8, Step: 31, Loss: 1.2742
# Epoch: 8, Step: 62, Loss: 1.2550
# Epoch: 8, Step: 93, Loss: 1.2610
# Epoch: 8, Step: 124, Loss: 1.2588
# Epoch: 8, Step: 155, Loss: 1.2570
# Epoch: 8, Step: 186, Loss: 1.2615
# Epoch: 8, Step: 217, Loss: 1.2613
# Epoch: 8, Step: 248, Loss: 1.2614
# Epoch: 8, Step: 279, Loss: 1.2608
# Epoch: 8, Step: 310, Loss: 1.2611
# Epoch: 8, Step: 341, Loss: 1.2570
# Epoch: 8, Step: 372, Loss: 1.2591
# Epoch: 8, Step: 403, Loss: 1.2578
# Epoch: 8, Step: 434, Loss: 1.2619
# Epoch: 8, Step: 465, Loss: 1.2599
# Epoch: 8, Step: 496, Loss: 1.2610
# Epoch: 8, Step: 527, Loss: 1.2624
# Epoch: 8, Step: 558, Loss: 1.2605
# Epoch: 8, Step: 589, Loss: 1.2606
# Epoch: 8, Step: 620, Loss: 1.2597
# Epoch: 8, Step: 651, Loss: 1.2600
# Epoch: 8, Step: 682, Loss: 1.2600
# Epoch: 8, Step: 713, Loss: 1.2596
# Epoch: 8, Step: 744, Loss: 1.2584
# Epoch: 8, Step: 775, Loss: 1.2586
# Epoch: 8, Step: 806, Loss: 1.2571
# Epoch: 8, Step: 837, Loss: 1.2581
# Epoch: 8, Step: 868, Loss: 1.2582
# Epoch: 8, Step: 899, Loss: 1.2567
# Epoch: 8, Step: 930, Loss: 1.2568
# Epoch: 8, Step: 938, Loss: 1.2561
# Train Accuracy: 57.79%, Test Accuracy: 57.27%
# Epoch: 9, Step: 31, Loss: 1.2676
# Epoch: 9, Step: 62, Loss: 1.2619
# Epoch: 9, Step: 93, Loss: 1.2699
# Epoch: 9, Step: 124, Loss: 1.2529
# Epoch: 9, Step: 155, Loss: 1.2488
# Epoch: 9, Step: 186, Loss: 1.2532
# Epoch: 9, Step: 217, Loss: 1.2495
# Epoch: 9, Step: 248, Loss: 1.2439
# Epoch: 9, Step: 279, Loss: 1.2382
# Epoch: 9, Step: 310, Loss: 1.2351
# Epoch: 9, Step: 341, Loss: 1.2383
# Epoch: 9, Step: 372, Loss: 1.2417
# Epoch: 9, Step: 403, Loss: 1.2425
# Epoch: 9, Step: 434, Loss: 1.2401
# Epoch: 9, Step: 465, Loss: 1.2434
# Epoch: 9, Step: 496, Loss: 1.2441
# Epoch: 9, Step: 527, Loss: 1.2432
# Epoch: 9, Step: 558, Loss: 1.2440
# Epoch: 9, Step: 589, Loss: 1.2442
# Epoch: 9, Step: 620, Loss: 1.2465
# Epoch: 9, Step: 651, Loss: 1.2474
# Epoch: 9, Step: 682, Loss: 1.2481
# Epoch: 9, Step: 713, Loss: 1.2476
# Epoch: 9, Step: 744, Loss: 1.2477
# Epoch: 9, Step: 775, Loss: 1.2487
# Epoch: 9, Step: 806, Loss: 1.2489
# Epoch: 9, Step: 837, Loss: 1.2495
# Epoch: 9, Step: 868, Loss: 1.2497
# Epoch: 9, Step: 899, Loss: 1.2481
# Epoch: 9, Step: 930, Loss: 1.2473
# Epoch: 9, Step: 938, Loss: 1.2471
# Train Accuracy: 58.04%, Test Accuracy: 57.23%
# Epoch: 10, Step: 31, Loss: 1.2278
# Epoch: 10, Step: 62, Loss: 1.2225
# Epoch: 10, Step: 93, Loss: 1.2385
# Epoch: 10, Step: 124, Loss: 1.2314
# Epoch: 10, Step: 155, Loss: 1.2345
# Epoch: 10, Step: 186, Loss: 1.2414
# Epoch: 10, Step: 217, Loss: 1.2393
# Epoch: 10, Step: 248, Loss: 1.2369
# Epoch: 10, Step: 279, Loss: 1.2363
# Epoch: 10, Step: 310, Loss: 1.2362
# Epoch: 10, Step: 341, Loss: 1.2355
# Epoch: 10, Step: 372, Loss: 1.2352
# Epoch: 10, Step: 403, Loss: 1.2395
# Epoch: 10, Step: 434, Loss: 1.2378
# Epoch: 10, Step: 465, Loss: 1.2388
# Epoch: 10, Step: 496, Loss: 1.2391
# Epoch: 10, Step: 527, Loss: 1.2384
# Epoch: 10, Step: 558, Loss: 1.2405
# Epoch: 10, Step: 589, Loss: 1.2408
# Epoch: 10, Step: 620, Loss: 1.2396
# Epoch: 10, Step: 651, Loss: 1.2395
# Epoch: 10, Step: 682, Loss: 1.2390
# Epoch: 10, Step: 713, Loss: 1.2378
# Epoch: 10, Step: 744, Loss: 1.2394
# Epoch: 10, Step: 775, Loss: 1.2398
# Epoch: 10, Step: 806, Loss: 1.2402
# Epoch: 10, Step: 837, Loss: 1.2400
# Epoch: 10, Step: 868, Loss: 1.2397
# Epoch: 10, Step: 899, Loss: 1.2403
# Epoch: 10, Step: 930, Loss: 1.2402
# Epoch: 10, Step: 938, Loss: 1.2396
# Train Accuracy: 58.18%, Test Accuracy: 57.89%
# 869.5 examples/sec on: [cuda:0]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 76
#      74 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#      75 # 训练模型
# ---> 76 train(net, train_loader, test_loader, epochs, lr, device)
#      77 # 加载保存的模型
#      78 # net.load_state_dict(torch.load("./model/AlexNet_Epoch20_Accuracy91.38%.pth"))
#      79 def show_predict():
#      80     # 预测结果图像可视化
#
# Cell In[1], line 71, in train(net, train_iter, test_iter, epochs, lr, device)
#      67     print(
#      68         f'Train Accuracy: {train_acc*100:.2f}%, Test Accuracy: {test_acc*100:.2f}%')
#      69 print(f'{metric[2] * epochs / timer.sum():.1f} examples/sec '
#      70       f'on: [{str(device)}]')
# ---> 71 torch.save(net.state_dict(),
#      72            f"./model/AlexNet_Epoch{epochs}_Accuracy{test_acc*100:.2f}%.pth")
#
# File d:\1-programme\porgramme\miniconda3\envs\test1\lib\site-packages\torch\serialization.py:627, in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     624 _check_save_filelike(f)
#     626 if _use_new_zipfile_serialization:
# --> 627     with _open_zipfile_writer(f) as opened_zipfile:
#     628         _save(obj, opened_zipfile, pickle_module, pickle_protocol, _disable_byteorder_record)
#     629         return
#
# File d:\1-programme\porgramme\miniconda3\envs\test1\lib\site-packages\torch\serialization.py:501, in _open_zipfile_writer(name_or_buffer)
#     499 else:
#     500     container = _open_zipfile_writer_buffer
# --> 501 return container(name_or_buffer)
#
# File d:\1-programme\porgramme\miniconda3\envs\test1\lib\site-packages\torch\serialization.py:472, in _open_zipfile_writer_file.__init__(self, name)
#     470     super().__init__(torch._C.PyTorchFileWriter(self.file_stream))
#     471 else:
# --> 472     super().__init__(torch._C.PyTorchFileWriter(self.name))
#
# RuntimeError: Parent directory ./model does not exist.
